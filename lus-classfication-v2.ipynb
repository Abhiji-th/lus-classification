# %%
import warnings
warnings.filterwarnings("ignore")
import os
import matplotlib.pyplot as plt
import random
from PIL import Image
import sklearn
from sklearn.model_selection import train_test_split
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import BinaryCrossentropy
from sklearn.model_selection import GroupShuffleSplit
from sklearn.model_selection import StratifiedGroupKFold
# Out:
# 2026-04-07 14:01:46.849475: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775570507.074090      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775570507.141892      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775570507.672125      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775570507.672184      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775570507.672187      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775570507.672189      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
base_path = '/kaggle/input/datasets/abhijithc/covid-pneumonia-lus-images/covid_pneumonia'

# %%
for cls in os.listdir(base_path):
    cls_path = os.path.join(base_path, cls)
    if os.path.isdir(cls_path):
        print(f"{cls}: {len(os.listdir(cls_path))}")
# Out:
# pneumonia: 463
# covid: 524

# %%
def show_samples(class_path, class_name, n=5):
    images = os.listdir(class_path)
    samples = random.sample(images, min(n, len(images)))

    plt.figure(figsize=(15, 3))
    for i, img_name in enumerate(samples):
        img_path = os.path.join(class_path, img_name)
        img = Image.open(img_path)

        plt.subplot(1, n, i+1)
        plt.imshow(img)
        plt.title(class_name)
        plt.axis('off')
    plt.show()

for cls in os.listdir(base_path):
    cls_path = os.path.join(base_path, cls)
    if os.path.isdir(cls_path):
        show_samples(cls_path, cls)

# %%
def get_video_id(path):
    filename = os.path.basename(path)
    filename = filename.split('.')[0]
    filename = filename.replace('-', '_')
    parts = filename.split('_')
    return '_'.join(parts[:2])

# %%
image_paths = []
labels = []

for label in os.listdir(base_path):
    class_path = os.path.join(base_path, label)
    for img in os.listdir(class_path):
        image_paths.append(os.path.join(class_path, img))
        labels.append(label)

df = pd.DataFrame({
    "filename": image_paths,
    "label": labels
})

df["video_id"] = df["filename"].apply(get_video_id)
df.tail()
# Out:
#                                               filename  label  \
# 982  /kaggle/input/datasets/abhijithc/covid-pneumon...  covid
# 983  /kaggle/input/datasets/abhijithc/covid-pneumon...  covid
# 984  /kaggle/input/datasets/abhijithc/covid-pneumon...  covid
# 985  /kaggle/input/datasets/abhijithc/covid-pneumon...  covid
# 986  /kaggle/input/datasets/abhijithc/covid-pneumon...  covid
#
#                 video_id
# 982            Cov_Atlas
# 983          Cov_denault
# 984  Cov_recommendations
# 985           Cov_convex
# 986           Cov_convex

# %%
video_df = df.groupby("video_id").first().reset_index()

print(video_df['label'].value_counts())
# Out:
# label
# covid        11
# pneumonia    10
# Name: count, dtype: int64

# %%
video_sizes = df.groupby("video_id").size()

video_info = video_df.copy()
video_info["num_frames"] = video_info["video_id"].map(video_sizes)

print(video_info.sort_values("num_frames", ascending=False).head(10))
# Out:
#                video_id                                           filename  \
# 19     Pneu_northumbria  /kaggle/input/datasets/abhijithc/covid-pneumon...
# 5            Cov_convex  /kaggle/input/datasets/abhijithc/covid-pneumon...
# 0             Cov_Atlas  /kaggle/input/datasets/abhijithc/covid-pneumon...
# 4        Cov_combatting  /kaggle/input/datasets/abhijithc/covid-pneumon...
# 6           Cov_denault  /kaggle/input/datasets/abhijithc/covid-pneumon...
# 12             Pneu_Avi  /kaggle/input/datasets/abhijithc/covid-pneumon...
# 8   Cov_recommendations  /kaggle/input/datasets/abhijithc/covid-pneumon...
# 11           Pneu_Atlas  /kaggle/input/datasets/abhijithc/covid-pneumon...
# 7            Cov_emdocs  /kaggle/input/datasets/abhijithc/covid-pneumon...
# 20      pneu_radiopaeda  /kaggle/input/datasets/abhijithc/covid-pneumon...
#
#         label  num_frames
# 19  pneumonia         272
# 5       covid         150
# 0       covid          93
# 4       covid          88
# 6       covid          86
# 12  pneumonia          83
# 8       covid          50
# 11  pneumonia          34
# 7       covid          31
# 20  pneumonia          23

# %%
ggs = GroupShuffleSplit(test_size=0.5, random_state=42)

train_idx, tmp_idx = next(
    ggs.split(df, groups=df["video_id"])
)

train_df = df.iloc[train_idx]
tmp_df = df.iloc[tmp_idx]

ggs2 = GroupShuffleSplit(test_size=0.5, random_state=42)

val_idx, test_idx = next(
    ggs2.split(tmp_df, groups=tmp_df["video_id"])
)

val_df = tmp_df.iloc[val_idx]
test_df = tmp_df.iloc[test_idx]

# %%
print("Train:\n", train_df['label'].value_counts(normalize=True))
print("Val:\n", val_df['label'].value_counts(normalize=True))
print("Test:\n", test_df['label'].value_counts(normalize=True))
# Out:
# Train:
#  label
# pneumonia    0.64214
# covid        0.35786
# Name: proportion, dtype: float64
# Val:
#  label
# covid        0.925926
# pneumonia    0.074074
# Name: proportion, dtype: float64
# Test:
#  label
# covid        0.635838
# pneumonia    0.364162
# Name: proportion, dtype: float64

# %%
train_df = pd.DataFrame({
    "x": train_df["filename"],
    "y": train_df["label"]
}) 

val_df = pd.DataFrame({
    "x": val_df["filename"],
    "y": val_df["label"]
})

test_df = pd.DataFrame({
    "x": test_df["filename"],
    "y": test_df["label"]
})

# %%
train_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.vgg16.preprocess_input).flow_from_dataframe(
    dataframe = train_df,
    x_col="x",
    y_col="y",
    target_size=(224, 224),
    color_mode = "rgb",
    batch_size=32,
    class_mode="binary",
    shuffle=True,
    seed=42
)

val_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.vgg16.preprocess_input).flow_from_dataframe(
    dataframe = val_df,
    x_col="x",
    y_col="y",
    target_size=(224, 224),
    color_mode = "rgb",
    batch_size=32,
    class_mode="binary",
    shuffle=False,
)

test_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.vgg16.preprocess_input).flow_from_dataframe(
    dataframe = test_df,
    x_col="x",
    y_col="y",
    target_size=(224, 224),
    color_mode = "rgb",
    batch_size=32,
    class_mode="binary",
    shuffle=False,
)
# Out:
# Found 598 validated image filenames belonging to 2 classes.
# Found 216 validated image filenames belonging to 2 classes.
# Found 173 validated image filenames belonging to 2 classes.

# %%
images, labels = next(train_batches)

# %%
plt.figure(figsize=(15,5))

for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(images[i])
    plt.title(labels[i])
    plt.axis('off')

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-123.68..100.061].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-123.68..114.061].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-123.68..126.061].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-123.68..84.061].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-123.68..127.061].

# %%
model = Sequential([
    Conv2D(filters=32, kernel_size=(3,3), padding="same", activation="relu", input_shape=(224, 224, 3)),
    MaxPooling2D(pool_size=(2,2), strides=2),
    Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu", input_shape=(224, 224, 3)),
    MaxPooling2D(pool_size=(2,2), strides=2),
    Flatten(),
    Dense(units=1, activation="sigmoid")
])
# Out:
# I0000 00:00:1775570536.432894      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1775570536.439222      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 200704)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │       200,705 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 220,097 (859.75 KB)
#  Trainable params: 220,097 (859.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])

# %%
model.fit(x=train_batches, validation_data=val_batches, epochs=10, verbose=2)
# Out:
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775570539.616652      76 service.cc:152] XLA service 0x7def041070b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1775570539.616711      76 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1775570539.616717      76 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1775570539.981284      76 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1775570543.532370      76 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 19/19 - 14s - 747ms/step - accuracy: 0.7090 - loss: 8.2330 - val_accuracy: 1.0000 - val_loss: 2.5222e-04
# Epoch 2/10
# 19/19 - 3s - 158ms/step - accuracy: 0.9114 - loss: 1.0657 - val_accuracy: 1.0000 - val_loss: 1.2579e-10
# Epoch 3/10
# 19/19 - 3s - 154ms/step - accuracy: 0.9816 - loss: 0.2484 - val_accuracy: 1.0000 - val_loss: 2.6992e-08
# Epoch 4/10
# 19/19 - 3s - 161ms/step - accuracy: 0.9933 - loss: 0.0602 - val_accuracy: 1.0000 - val_loss: 2.7447e-06
# Epoch 5/10
# 19/19 - 3s - 173ms/step - accuracy: 0.9967 - loss: 0.0344 - val_accuracy: 0.9815 - val_loss: 0.0890
# Epoch 6/10
# 19/19 - 3s - 160ms/step - accuracy: 0.9967 - loss: 0.0293 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 7/10
# 19/19 - 3s - 164ms/step - accuracy: 0.9950 - loss: 0.0164 - val_accuracy: 1.0000 - val_loss: 7.1863e-06
# Epoch 8/10
# 19/19 - 3s - 164ms/step - accuracy: 0.9950 - loss: 0.0190 - val_accuracy: 1.0000 - val_loss: 8.0376e-08
# Epoch 9/10
# 19/19 - 3s - 157ms/step - accuracy: 0.9967 - loss: 0.0079 - val_accuracy: 0.9769 - val_loss: 0.1145
# Epoch 10/10
# 19/19 - 3s - 159ms/step - accuracy: 0.9983 - loss: 0.0024 - val_accuracy: 0.9954 - val_loss: 0.0055

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(test_batches)
y_pred = (y_pred > 0.5).astype(int)

print(confusion_matrix(test_batches.classes, y_pred))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 287ms/step
# [[72 38]
#  [ 8 55]]

# %%
test_loss, test_acc = model.evaluate(test_batches)
print(test_acc)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.7778 - loss: 1.7663
# 0.7341040372848511
